# %%
import aiohttp
import asyncio
import csv
import os
import re
from bs4 import BeautifulSoup

async def fetch_page(session, page_id, failed_ids_file):
    url = f"https://simple.wikipedia.org/wiki/?curid={page_id}"
    retries = 3
    for attempt in range(retries):
        try:
            async with session.get(url) as response:
                if response.status == 200:
                    text = await response.text()
                    title, content = parse_page(text)
                    return [page_id, title, content]
                elif response.status == 429:
                    await asyncio.sleep(30)
                else:
                    print(f"Không lấy được trang {page_id}, mã lỗi: {response.status}")
                    raise Exception(f"HTTP {response.status}")
        except Exception as e:
            print(f"Lỗi khi crawl trang {page_id}: {e}")
    
    print(f"Thử lại thất bại cho trang {page_id}. Lưu ID vào file thất bại.")
    with open(failed_ids_file, mode='a', encoding='utf-8') as failed_file:
        failed_file.write(f"{page_id}\n")
    return [page_id, "Error", ""]

def parse_page(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    # Lấy tiêu đề
    title = soup.title.text if soup.title else "Không tìm thấy tiêu đề"
    # Loại bỏ chuỗi không mong muốn khỏi tiêu đề
    title = title.replace(" - Simple English Wikipedia, the free encyclopedia", "").strip()
    # Lấy nội dung chính
    content_div = soup.find('div', {'id': 'mw-content-text'})
    content = ""
    if content_div:
        paragraphs = content_div.find_all('p')
        for para in paragraphs:
            para_text = para.text.strip()
            
            # Loại bỏ các thẻ kiểu \displaystyle hoặc thẻ LaTeX khác
            para_text = re.sub(r'\\displaystyle[^\s]*', '', para_text)
            
            # Thay thế các dấu xuống dòng thừa bằng dấu cách
            para_text = re.sub(r'\s+', ' ', para_text)  # Thay thế các khoảng trắng thừa, bao gồm cả dấu xuống dòng

            # Thêm vào nội dung cuối cùng
            content += para_text + " "  # Thêm dấu cách giữa các đoạn văn bản
    else:
        content = "Không tìm thấy nội dung chính"
    
    return title, content

async def fetch_group(ids, filename, semaphore, failed_ids_file, requests_per_second=40):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for i, page_id in enumerate(ids):
            async with semaphore:
                tasks.append(fetch_page(session, page_id, failed_ids_file))
            if (i + 1) % requests_per_second == 0:
                await asyncio.sleep(1)
        results = await asyncio.gather(*tasks)
        with open(filename, mode='a', encoding='utf-8', newline='') as file:
            writer = csv.writer(file)
            writer.writerows(results)
        print(f"Đã lưu {len(ids)} trang vào file '{filename}'")

async def crawl_all(ids, output_file, failed_ids_file, group_size=500, max_concurrent_requests=80):
    semaphore = asyncio.Semaphore(max_concurrent_requests)
    groups = [ids[i:i+group_size] for i in range(0, len(ids), group_size)]
    if not os.path.exists(output_file):
        with open(output_file, mode='w', encoding='utf-8', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["ID", "Title", "Content"])
    if not os.path.exists(failed_ids_file):
        open(failed_ids_file, 'w', encoding='utf-8').close()
    for i, group in enumerate(groups):
        print(f"Crawl nhóm {i+1}/{len(groups)} ({len(group)} trang)...")
        await fetch_group(group, output_file, semaphore, failed_ids_file, requests_per_second=40)
        print(f"Hoàn thành nhóm {i+1}/{len(groups)}!")
        if (i + 1) % 10 == 0:
            print("Nghỉ 30 giây để tránh lỗi 429...")
            await asyncio.sleep(60)

async def run_crawl(ids, output_file, failed_ids_file):
    await crawl_all(ids, output_file, failed_ids_file)
import nest_asyncio
nest_asyncio.apply()
if __name__ == "__main__":
    input_file = "/kaggle/input/faild-tong-hop/failed16.txt"
    output_file = "/kaggle/working/wki-faild.csv"
    failed_ids_file = "/kaggle/working/failed.txt"

    if not os.path.exists(input_file):
        print(f"Không tìm thấy file '{input_file}'!")
        exit()
    
    with open(input_file, mode='r', encoding='utf-8') as file:
        ids = [line for line in file]
    
    print(f"Đã đọc {len(ids)} ID từ file '{input_file}'.")
    # Chạy trực tiếp
    await run_crawl(ids, output_file, failed_ids_file)
# Out:
# Đã đọc 6298 ID từ file '/kaggle/input/faild-tong-hop/failed16.txt'.
# Crawl nhóm 1/13 (500 trang)...
# Không lấy được trang 18823
# , mã lỗi: 404
# Lỗi khi crawl trang 18823
# : HTTP 404
# Không lấy được trang 35534
# , mã lỗi: 404
# Lỗi khi crawl trang 35534
# : HTTP 404
# Không lấy được trang 45500
# , mã lỗi: 404
# Lỗi khi crawl trang 45500
# : HTTP 404
# Không lấy được trang 39264
# , mã lỗi: 404
# Lỗi khi crawl trang 39264
# : HTTP 404
# Không lấy được trang 18505
# , mã lỗi: 404
# Lỗi khi crawl trang 18505
# : HTTP 404
# Không lấy được trang 47006
# , mã lỗi: 404
# Lỗi khi crawl trang 47006
# : HTTP 404
# Không lấy được trang 67994
# , mã lỗi: 404
# Lỗi khi crawl trang 67994
# : HTTP 404
# Không lấy được trang 35534
# , mã lỗi: 404
# Lỗi khi crawl trang 35534
# : HTTP 404
# Không lấy được trang 18823
# , mã lỗi: 404
# Lỗi khi crawl trang 18823
# : HTTP 404
# Không lấy được trang 45500
# , mã lỗi: 404
# Lỗi khi crawl trang 45500
# : HTTP 404
# Không lấy được trang 47006
# , mã lỗi: 404
# Lỗi khi crawl trang 47006
# : HTTP 404
# Không lấy được trang 39264
# , mã lỗi: 404
# Lỗi khi crawl trang 39264
# : HTTP 404
# Không lấy được trang 18505
# , mã lỗi: 404
# Lỗi khi crawl trang 18505
# : HTTP 404
# Không lấy được trang 67994
# , mã lỗi: 404
# Lỗi khi crawl trang 67994
# : HTTP 404
# Không lấy được trang 35534
# , mã lỗi: 404
# Lỗi khi crawl trang 35534
# : HTTP 404
# Thử lại thất bại cho trang 35534
# . Lưu ID vào file thất bại.
# Không lấy được trang 18823
# , mã lỗi: 404
# Lỗi khi crawl trang 18823
# : HTTP 404
# Thử lại thất bại cho trang 18823
# . Lưu ID vào file thất bại.
# Không lấy được trang 45500
# , mã lỗi: 404
# Lỗi khi crawl trang 45500
# : HTTP 404
# Thử lại thất bại cho trang 45500
# . Lưu ID vào file thất bại.
# Không lấy được trang 47006
# , mã lỗi: 404
# Lỗi khi crawl trang 47006
# : HTTP 404
# Thử lại thất bại cho trang 47006
# . Lưu ID vào file thất bại.
# Không lấy được trang 39264
# , mã lỗi: 404
# Lỗi khi crawl trang 39264
# : HTTP 404
# Thử lại thất bại cho trang 39264
# . Lưu ID vào file thất bại.
# Không lấy được trang 18505
# , mã lỗi: 404
# Lỗi khi crawl trang 18505
# : HTTP 404
# Thử lại thất bại cho trang 18505
# . Lưu ID vào file thất bại.
# Không lấy được trang 67994
# , mã lỗi: 404
# Lỗi khi crawl trang 67994
# : HTTP 404
# Thử lại thất bại cho trang 67994
# . Lưu ID vào file thất bại.
# Không lấy được trang 95996
# , mã lỗi: 404
# Lỗi khi crawl trang 95996
# : HTTP 404
# Không lấy được trang 95996
# , mã lỗi: 404
# Lỗi khi crawl trang 95996
# : HTTP 404
# Thử lại thất bại cho trang 95996
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 1/13!
# Crawl nhóm 2/13 (500 trang)...
# Không lấy được trang 134404
# , mã lỗi: 404
# Lỗi khi crawl trang 134404
# : HTTP 404
# Không lấy được trang 134404
# , mã lỗi: 404
# Lỗi khi crawl trang 134404
# : HTTP 404
# Không lấy được trang 134404
# , mã lỗi: 404
# Lỗi khi crawl trang 134404
# : HTTP 404
# Thử lại thất bại cho trang 134404
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 2/13!
# Crawl nhóm 3/13 (500 trang)...
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 3/13!
# Crawl nhóm 4/13 (500 trang)...
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 4/13!
# Crawl nhóm 5/13 (500 trang)...
# Không lấy được trang 328755
# , mã lỗi: 404
# Lỗi khi crawl trang 328755
# : HTTP 404
# Không lấy được trang 328755
# , mã lỗi: 404
# Lỗi khi crawl trang 328755
# : HTTP 404
# Thử lại thất bại cho trang 328755
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 5/13!
# Crawl nhóm 6/13 (500 trang)...
# Không lấy được trang 467411
# , mã lỗi: 404
# Lỗi khi crawl trang 467411
# : HTTP 404
# Thử lại thất bại cho trang 467411
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 6/13!
# Crawl nhóm 7/13 (500 trang)...
# Thử lại thất bại cho trang 600350
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600313
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600323
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600364
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600340
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600302
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600326
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600231
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600312
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600315
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600404
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600235
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600339
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600295
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600282
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600365
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600234
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600173
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600398
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600314
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600307
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600373
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 600332
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 7/13!
# Crawl nhóm 8/13 (500 trang)...
# Không lấy được trang 615169
# , mã lỗi: 404
# Lỗi khi crawl trang 615169
# : HTTP 404
# Không lấy được trang 615162
# , mã lỗi: 404
# Lỗi khi crawl trang 615162
# : HTTP 404
# Không lấy được trang 615169
# , mã lỗi: 404
# Lỗi khi crawl trang 615169
# : HTTP 404
# Thử lại thất bại cho trang 615169
# . Lưu ID vào file thất bại.
# Không lấy được trang 615162
# , mã lỗi: 404
# Lỗi khi crawl trang 615162
# : HTTP 404
# Thử lại thất bại cho trang 615162
# . Lưu ID vào file thất bại.
# Không lấy được trang 625705
# , mã lỗi: 404
# Lỗi khi crawl trang 625705
# : HTTP 404
# Không lấy được trang 625705
# , mã lỗi: 404
# Lỗi khi crawl trang 625705
# : HTTP 404
# Thử lại thất bại cho trang 625705
# . Lưu ID vào file thất bại.
# Không lấy được trang 669662
# , mã lỗi: 404
# Lỗi khi crawl trang 669662
# : HTTP 404
# Thử lại thất bại cho trang 669662
# . Lưu ID vào file thất bại.
# Không lấy được trang 711343
# , mã lỗi: 404
# Lỗi khi crawl trang 711343
# : HTTP 404
# Thử lại thất bại cho trang 711343
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 690713
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 702733
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 690723
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 702702
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 690724
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 690722
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 8/13!
# Crawl nhóm 9/13 (500 trang)...
# Không lấy được trang 740308
# , mã lỗi: 404
# Lỗi khi crawl trang 740308
# : HTTP 404
# Không lấy được trang 754727
# , mã lỗi: 404
# Lỗi khi crawl trang 754727
# : HTTP 404
# Không lấy được trang 754727
# , mã lỗi: 404
# Lỗi khi crawl trang 754727
# : HTTP 404
# Không lấy được trang 740308
# , mã lỗi: 404
# Lỗi khi crawl trang 740308
# : HTTP 404
# Không lấy được trang 754727
# , mã lỗi: 404
# Lỗi khi crawl trang 754727
# : HTTP 404
# Thử lại thất bại cho trang 754727
# . Lưu ID vào file thất bại.
# Không lấy được trang 740308
# , mã lỗi: 404
# Lỗi khi crawl trang 740308
# : HTTP 404
# Thử lại thất bại cho trang 740308
# . Lưu ID vào file thất bại.
# Không lấy được trang 778670
# , mã lỗi: 404
# Lỗi khi crawl trang 778670
# : HTTP 404
# Thử lại thất bại cho trang 778670
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791428
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 772656
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 772669
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791488
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 771913
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791432
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791503
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791494
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791496
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791506
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792332
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792347
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 791502
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792343
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792339
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792344
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792358
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 794155
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 794151
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792355
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796655
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 792357
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796646
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 794019
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796647
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796627
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796658
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796657
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 796666
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 9/13!
# Crawl nhóm 10/13 (500 trang)...
# Không lấy được trang 805241
# , mã lỗi: 404
# Lỗi khi crawl trang 805241
# : HTTP 404
# Không lấy được trang 845025
# , mã lỗi: 404
# Lỗi khi crawl trang 845025
# : HTTP 404
# Không lấy được trang 889090
# , mã lỗi: 404
# Lỗi khi crawl trang 889090
# : HTTP 404
# Không lấy được trang 891911
# , mã lỗi: 404
# Lỗi khi crawl trang 891911
# : HTTP 404
# Không lấy được trang 845025
# , mã lỗi: 404
# Lỗi khi crawl trang 845025
# : HTTP 404
# Không lấy được trang 805241
# , mã lỗi: 404
# Lỗi khi crawl trang 805241
# : HTTP 404
# Không lấy được trang 891911
# , mã lỗi: 404
# Lỗi khi crawl trang 891911
# : HTTP 404
# Không lấy được trang 889090
# , mã lỗi: 404
# Lỗi khi crawl trang 889090
# : HTTP 404
# Không lấy được trang 845025
# , mã lỗi: 404
# Lỗi khi crawl trang 845025
# : HTTP 404
# Thử lại thất bại cho trang 845025
# . Lưu ID vào file thất bại.
# Không lấy được trang 805241
# , mã lỗi: 404
# Lỗi khi crawl trang 805241
# : HTTP 404
# Thử lại thất bại cho trang 805241
# . Lưu ID vào file thất bại.
# Không lấy được trang 891911
# , mã lỗi: 404
# Lỗi khi crawl trang 891911
# : HTTP 404
# Thử lại thất bại cho trang 891911
# . Lưu ID vào file thất bại.
# Không lấy được trang 889090
# , mã lỗi: 404
# Lỗi khi crawl trang 889090
# : HTTP 404
# Thử lại thất bại cho trang 889090
# . Lưu ID vào file thất bại.
# Không lấy được trang 917211
# , mã lỗi: 404
# Lỗi khi crawl trang 917211
# : HTTP 404
# Không lấy được trang 917211
# , mã lỗi: 404
# Lỗi khi crawl trang 917211
# : HTTP 404
# Thử lại thất bại cho trang 917211
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 10/13!
# Nghỉ 30 giây để tránh lỗi 429...
# Crawl nhóm 11/13 (500 trang)...
# Không lấy được trang 936888
# , mã lỗi: 404
# Lỗi khi crawl trang 936888
# : HTTP 404
# Không lấy được trang 936888
# , mã lỗi: 404
# Lỗi khi crawl trang 936888
# : HTTP 404
# Thử lại thất bại cho trang 936888
# . Lưu ID vào file thất bại.
# Không lấy được trang 949856
# , mã lỗi: 404
# Lỗi khi crawl trang 949856
# : HTTP 404
# Không lấy được trang 949856
# , mã lỗi: 404
# Lỗi khi crawl trang 949856
# : HTTP 404
# Thử lại thất bại cho trang 949856
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 11/13!
# Crawl nhóm 12/13 (500 trang)...
# Không lấy được trang 967293
# , mã lỗi: 404
# Lỗi khi crawl trang 967293
# : HTTP 404
# Không lấy được trang 1005070
# , mã lỗi: 404
# Lỗi khi crawl trang 1005070
# : HTTP 404
# Không lấy được trang 1005554
# , mã lỗi: 404
# Lỗi khi crawl trang 1005554
# : HTTP 404
# Không lấy được trang 967293
# , mã lỗi: 404
# Lỗi khi crawl trang 967293
# : HTTP 404
# Không lấy được trang 1005070
# , mã lỗi: 404
# Lỗi khi crawl trang 1005070
# : HTTP 404
# Không lấy được trang 1005554
# , mã lỗi: 404
# Lỗi khi crawl trang 1005554
# : HTTP 404
# Không lấy được trang 967293
# , mã lỗi: 404
# Lỗi khi crawl trang 967293
# : HTTP 404
# Thử lại thất bại cho trang 967293
# . Lưu ID vào file thất bại.
# Không lấy được trang 1005070
# , mã lỗi: 404
# Lỗi khi crawl trang 1005070
# : HTTP 404
# Thử lại thất bại cho trang 1005070
# . Lưu ID vào file thất bại.
# Không lấy được trang 1005554
# , mã lỗi: 404
# Lỗi khi crawl trang 1005554
# : HTTP 404
# Thử lại thất bại cho trang 1005554
# . Lưu ID vào file thất bại.
# Không lấy được trang 977753
# , mã lỗi: 404
# Lỗi khi crawl trang 977753
# : HTTP 404
# Không lấy được trang 977753
# , mã lỗi: 404
# Lỗi khi crawl trang 977753
# : HTTP 404
# Thử lại thất bại cho trang 977753
# . Lưu ID vào file thất bại.
# Không lấy được trang 989981
# , mã lỗi: 404
# Lỗi khi crawl trang 989981
# : HTTP 404
# Không lấy được trang 989981
# , mã lỗi: 404
# Lỗi khi crawl trang 989981
# : HTTP 404
# Thử lại thất bại cho trang 989981
# . Lưu ID vào file thất bại.
# Không lấy được trang 998023
# , mã lỗi: 404
# Lỗi khi crawl trang 998023
# : HTTP 404
# Không lấy được trang 998023
# , mã lỗi: 404
# Lỗi khi crawl trang 998023
# : HTTP 404
# Thử lại thất bại cho trang 998023
# . Lưu ID vào file thất bại.
# Không lấy được trang 1032782
# , mã lỗi: 404
# Lỗi khi crawl trang 1032782
# : HTTP 404
# Thử lại thất bại cho trang 1032782
# . Lưu ID vào file thất bại.
# Không lấy được trang 1034324
# , mã lỗi: 404
# Lỗi khi crawl trang 1034324
# : HTTP 404
# Thử lại thất bại cho trang 1034324
# . Lưu ID vào file thất bại.
# Không lấy được trang 1035765
# , mã lỗi: 404
# Lỗi khi crawl trang 1035765
# : HTTP 404
# Thử lại thất bại cho trang 1035765
# . Lưu ID vào file thất bại.
# Không lấy được trang 1032893
# , mã lỗi: 404
# Lỗi khi crawl trang 1032893
# : HTTP 404
# Thử lại thất bại cho trang 1032893
# . Lưu ID vào file thất bại.
# Không lấy được trang 1051232
# , mã lỗi: 404
# Lỗi khi crawl trang 1051232
# : HTTP 404
# Thử lại thất bại cho trang 1051232
# . Lưu ID vào file thất bại.
# Không lấy được trang 1055316
# , mã lỗi: 404
# Lỗi khi crawl trang 1055316
# : HTTP 404
# Thử lại thất bại cho trang 1055316
# . Lưu ID vào file thất bại.
# Không lấy được trang 1038208
# , mã lỗi: 404
# Lỗi khi crawl trang 1038208
# : HTTP 404
# Thử lại thất bại cho trang 1038208
# . Lưu ID vào file thất bại.
# Không lấy được trang 1077001
# , mã lỗi: 404
# Lỗi khi crawl trang 1077001
# : HTTP 404
# Thử lại thất bại cho trang 1077001
# . Lưu ID vào file thất bại.
# Không lấy được trang 1090577
# , mã lỗi: 404
# Lỗi khi crawl trang 1090577
# : HTTP 404
# Thử lại thất bại cho trang 1090577
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1084528
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1089246
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1089257
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1089267
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1082693
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1082692
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1082668
# . Lưu ID vào file thất bại.
# Thử lại thất bại cho trang 1082691
# . Lưu ID vào file thất bại.
# Đã lưu 500 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 12/13!
# Crawl nhóm 13/13 (298 trang)...
# Không lấy được trang 1093224
# , mã lỗi: 404
# Lỗi khi crawl trang 1093224
# : HTTP 404
# Không lấy được trang 1099833
# , mã lỗi: 404
# Lỗi khi crawl trang 1099833
# : HTTP 404
# Không lấy được trang 1099832
# , mã lỗi: 404
# Lỗi khi crawl trang 1099832
# : HTTP 404
# Không lấy được trang 1113852
# , mã lỗi: 404
# Lỗi khi crawl trang 1113852
# : HTTP 404
# Không lấy được trang 1142274
# , mã lỗi: 404
# Lỗi khi crawl trang 1142274
# : HTTP 404
# Không lấy được trang 1146450
# , mã lỗi: 404
# Lỗi khi crawl trang 1146450
# : HTTP 404
# Không lấy được trang 1146824
# , mã lỗi: 404
# Lỗi khi crawl trang 1146824
# : HTTP 404
# Không lấy được trang 1120971
# , mã lỗi: 404
# Lỗi khi crawl trang 1120971
# : HTTP 404
# Không lấy được trang 1151866
# , mã lỗi: 404
# Lỗi khi crawl trang 1151866
# : HTTP 404
# Không lấy được trang 1119566
# , mã lỗi: 404
# Lỗi khi crawl trang 1119566
# : HTTP 404
# Không lấy được trang 1150985
# , mã lỗi: 404
# Lỗi khi crawl trang 1150985
# : HTTP 404
# Không lấy được trang 1108870
# , mã lỗi: 404
# Lỗi khi crawl trang 1108870
# : HTTP 404
# Không lấy được trang 1152250
# , mã lỗi: 404
# Lỗi khi crawl trang 1152250
# : HTTP 404
# Không lấy được trang 1114055
# , mã lỗi: 404
# Lỗi khi crawl trang 1114055
# : HTTP 404
# Không lấy được trang 1108964
# , mã lỗi: 404
# Lỗi khi crawl trang 1108964
# : HTTP 404
# Không lấy được trang 1114100
# , mã lỗi: 404
# Lỗi khi crawl trang 1114100
# : HTTP 404
# Không lấy được trang 1120279
# , mã lỗi: 404
# Lỗi khi crawl trang 1120279
# : HTTP 404
# Không lấy được trang 1117375
# , mã lỗi: 404
# Lỗi khi crawl trang 1117375
# : HTTP 404
# Không lấy được trang 1120995
# , mã lỗi: 404
# Lỗi khi crawl trang 1120995
# : HTTP 404
# Không lấy được trang 1130686
# , mã lỗi: 404
# Lỗi khi crawl trang 1130686
# : HTTP 404
# Không lấy được trang 1140719
# , mã lỗi: 404
# Lỗi khi crawl trang 1140719
# : HTTP 404
# Không lấy được trang 1125653
# , mã lỗi: 404
# Lỗi khi crawl trang 1125653
# : HTTP 404
# Không lấy được trang 1132139
# , mã lỗi: 404
# Lỗi khi crawl trang 1132139
# : HTTP 404
# Không lấy được trang 1124987
# , mã lỗi: 404
# Lỗi khi crawl trang 1124987
# : HTTP 404
# Không lấy được trang 1113992
# , mã lỗi: 404
# Lỗi khi crawl trang 1113992
# : HTTP 404
# Không lấy được trang 1125007
# , mã lỗi: 404
# Lỗi khi crawl trang 1125007
# : HTTP 404
# Không lấy được trang 1121297
# , mã lỗi: 404
# Lỗi khi crawl trang 1121297
# : HTTP 404
# Không lấy được trang 1121808
# , mã lỗi: 404
# Lỗi khi crawl trang 1121808
# : HTTP 404
# Không lấy được trang 1132450
# , mã lỗi: 404
# Lỗi khi crawl trang 1132450
# : HTTP 404
# Không lấy được trang 1131047
# , mã lỗi: 404
# Lỗi khi crawl trang 1131047
# : HTTP 404
# Không lấy được trang 1133240
# , mã lỗi: 404
# Lỗi khi crawl trang 1133240
# : HTTP 404
# Không lấy được trang 1125652
# , mã lỗi: 404
# Lỗi khi crawl trang 1125652
# : HTTP 404
# Không lấy được trang 1130262
# , mã lỗi: 404
# Lỗi khi crawl trang 1130262
# : HTTP 404
# Không lấy được trang 1134155
# , mã lỗi: 404
# Lỗi khi crawl trang 1134155
# : HTTP 404
# Không lấy được trang 1120969
# , mã lỗi: 404
# Lỗi khi crawl trang 1120969
# : HTTP 404
# Không lấy được trang 1130266
# , mã lỗi: 404
# Lỗi khi crawl trang 1130266
# : HTTP 404
# Không lấy được trang 1124998
# , mã lỗi: 404
# Lỗi khi crawl trang 1124998
# : HTTP 404
# Không lấy được trang 1130880
# , mã lỗi: 404
# Lỗi khi crawl trang 1130880
# : HTTP 404
# Không lấy được trang 1121797
# , mã lỗi: 404
# Lỗi khi crawl trang 1121797
# : HTTP 404
# Không lấy được trang 1152776
# , mã lỗi: 404
# Lỗi khi crawl trang 1152776
# : HTTP 404
# Không lấy được trang 1146503
# , mã lỗi: 404
# Lỗi khi crawl trang 1146503
# : HTTP 404
# Không lấy được trang 1151503
# , mã lỗi: 404
# Lỗi khi crawl trang 1151503
# : HTTP 404
# Không lấy được trang 1151681
# , mã lỗi: 404
# Lỗi khi crawl trang 1151681
# : HTTP 404
# Không lấy được trang 1146646
# , mã lỗi: 404
# Lỗi khi crawl trang 1146646
# : HTTP 404
# Không lấy được trang 1147452
# , mã lỗi: 404
# Lỗi khi crawl trang 1147452
# : HTTP 404
# Không lấy được trang 1153119
# , mã lỗi: 404
# Lỗi khi crawl trang 1153119
# : HTTP 404
# Không lấy được trang 1153129
# , mã lỗi: 404
# Lỗi khi crawl trang 1153129
# : HTTP 404
# Không lấy được trang 1153241
# , mã lỗi: 404
# Lỗi khi crawl trang 1153241
# : HTTP 404
# Không lấy được trang 1153252
# , mã lỗi: 404
# Lỗi khi crawl trang 1153252
# : HTTP 404
# Không lấy được trang 1152749
# , mã lỗi: 404
# Lỗi khi crawl trang 1152749
# : HTTP 404
# Không lấy được trang 1153774
# , mã lỗi: 404
# Lỗi khi crawl trang 1153774
# : HTTP 404
# Không lấy được trang 1153661
# , mã lỗi: 404
# Lỗi khi crawl trang 1153661
# : HTTP 404
# Không lấy được trang 1153769
# , mã lỗi: 404
# Lỗi khi crawl trang 1153769
# : HTTP 404
# Không lấy được trang 1153006
# , mã lỗi: 404
# Lỗi khi crawl trang 1153006
# : HTTP 404
# Không lấy được trang 1152767
# , mã lỗi: 404
# Lỗi khi crawl trang 1152767
# : HTTP 404
# Không lấy được trang 1153234
# , mã lỗi: 404
# Lỗi khi crawl trang 1153234
# : HTTP 404
# Không lấy được trang 1153347
# , mã lỗi: 404
# Lỗi khi crawl trang 1153347
# : HTTP 404
# Không lấy được trang 1153327
# , mã lỗi: 404
# Lỗi khi crawl trang 1153327
# : HTTP 404
# Không lấy được trang 1153031
# , mã lỗi: 404
# Lỗi khi crawl trang 1153031
# : HTTP 404
# Không lấy được trang 1156470
# , mã lỗi: 404
# Lỗi khi crawl trang 1156470
# : HTTP 404
# Không lấy được trang 1156451
# , mã lỗi: 404
# Lỗi khi crawl trang 1156451
# : HTTP 404
# Không lấy được trang 1156691
# , mã lỗi: 404
# Lỗi khi crawl trang 1156691
# : HTTP 404
# Không lấy được trang 1155774
# , mã lỗi: 404
# Lỗi khi crawl trang 1155774
# : HTTP 404
# Không lấy được trang 1156261
# , mã lỗi: 404
# Lỗi khi crawl trang 1156261
# : HTTP 404
# Không lấy được trang 1099833
# , mã lỗi: 404
# Lỗi khi crawl trang 1099833
# : HTTP 404
# Không lấy được trang 1093224
# , mã lỗi: 404
# Lỗi khi crawl trang 1093224
# : HTTP 404
# Không lấy được trang 1099832
# , mã lỗi: 404
# Lỗi khi crawl trang 1099832
# : HTTP 404
# Không lấy được trang 1157589
# , mã lỗi: 404
# Lỗi khi crawl trang 1157589
# : HTTP 404
# Không lấy được trang 1157570
# , mã lỗi: 404
# Lỗi khi crawl trang 1157570
# : HTTP 404
# Không lấy được trang 1113852
# , mã lỗi: 404
# Lỗi khi crawl trang 1113852
# : HTTP 404
# Không lấy được trang 1146824
# , mã lỗi: 404
# Lỗi khi crawl trang 1146824
# : HTTP 404
# Không lấy được trang 1146450
# , mã lỗi: 404
# Lỗi khi crawl trang 1146450
# : HTTP 404
# Không lấy được trang 1142274
# , mã lỗi: 404
# Lỗi khi crawl trang 1142274
# : HTTP 404
# Không lấy được trang 1120971
# , mã lỗi: 404
# Lỗi khi crawl trang 1120971
# : HTTP 404
# Không lấy được trang 1151866
# , mã lỗi: 404
# Lỗi khi crawl trang 1151866
# : HTTP 404
# Không lấy được trang 1108870
# , mã lỗi: 404
# Lỗi khi crawl trang 1108870
# : HTTP 404
# Không lấy được trang 1152250
# , mã lỗi: 404
# Lỗi khi crawl trang 1152250
# : HTTP 404
# Không lấy được trang 1119566
# , mã lỗi: 404
# Lỗi khi crawl trang 1119566
# : HTTP 404
# Không lấy được trang 1150985
# , mã lỗi: 404
# Lỗi khi crawl trang 1150985
# : HTTP 404
# Không lấy được trang 1157219
# , mã lỗi: 404
# Lỗi khi crawl trang 1157219
# : HTTP 404
# Không lấy được trang 1114055
# , mã lỗi: 404
# Lỗi khi crawl trang 1114055
# : HTTP 404
# Không lấy được trang 1108964
# , mã lỗi: 404
# Lỗi khi crawl trang 1108964
# : HTTP 404
# Không lấy được trang 1114100
# , mã lỗi: 404
# Lỗi khi crawl trang 1114100
# : HTTP 404
# Không lấy được trang 1120279
# , mã lỗi: 404
# Lỗi khi crawl trang 1120279
# : HTTP 404
# Không lấy được trang 1140719
# , mã lỗi: 404
# Lỗi khi crawl trang 1140719
# : HTTP 404
# Không lấy được trang 1125653
# , mã lỗi: 404
# Lỗi khi crawl trang 1125653
# : HTTP 404
# Không lấy được trang 1117375
# , mã lỗi: 404
# Lỗi khi crawl trang 1117375
# : HTTP 404
# Không lấy được trang 1120995
# , mã lỗi: 404
# Lỗi khi crawl trang 1120995
# : HTTP 404
# Không lấy được trang 1130686
# , mã lỗi: 404
# Lỗi khi crawl trang 1130686
# : HTTP 404
# Không lấy được trang 1132139
# , mã lỗi: 404
# Lỗi khi crawl trang 1132139
# : HTTP 404
# Không lấy được trang 1125007
# , mã lỗi: 404
# Lỗi khi crawl trang 1125007
# : HTTP 404
# Không lấy được trang 1113992
# , mã lỗi: 404
# Lỗi khi crawl trang 1113992
# : HTTP 404
# Không lấy được trang 1121297
# , mã lỗi: 404
# Lỗi khi crawl trang 1121297
# : HTTP 404
# Không lấy được trang 1124987
# , mã lỗi: 404
# Lỗi khi crawl trang 1124987
# : HTTP 404
# Không lấy được trang 1121808
# , mã lỗi: 404
# Lỗi khi crawl trang 1121808
# : HTTP 404
# Không lấy được trang 1131047
# , mã lỗi: 404
# Lỗi khi crawl trang 1131047
# : HTTP 404
# Không lấy được trang 1132450
# , mã lỗi: 404
# Lỗi khi crawl trang 1132450
# : HTTP 404
# Không lấy được trang 1125652
# , mã lỗi: 404
# Lỗi khi crawl trang 1125652
# : HTTP 404
# Không lấy được trang 1134155
# , mã lỗi: 404
# Lỗi khi crawl trang 1134155
# : HTTP 404
# Không lấy được trang 1133240
# , mã lỗi: 404
# Lỗi khi crawl trang 1133240
# : HTTP 404
# Không lấy được trang 1130262
# , mã lỗi: 404
# Lỗi khi crawl trang 1130262
# : HTTP 404
# Không lấy được trang 1120969
# , mã lỗi: 404
# Lỗi khi crawl trang 1120969
# : HTTP 404
# Không lấy được trang 1130266
# , mã lỗi: 404
# Lỗi khi crawl trang 1130266
# : HTTP 404
# Không lấy được trang 1157397
# , mã lỗi: 404
# Lỗi khi crawl trang 1157397
# : HTTP 404
# Không lấy được trang 1157680
# , mã lỗi: 404
# Lỗi khi crawl trang 1157680
# : HTTP 404
# Không lấy được trang 1157375
# , mã lỗi: 404
# Lỗi khi crawl trang 1157375
# : HTTP 404
# Không lấy được trang 1156956
# , mã lỗi: 404
# Lỗi khi crawl trang 1156956
# : HTTP 404
# Không lấy được trang 1124998
# , mã lỗi: 404
# Lỗi khi crawl trang 1124998
# : HTTP 404
# Không lấy được trang 1121797
# , mã lỗi: 404
# Lỗi khi crawl trang 1121797
# : HTTP 404
# Không lấy được trang 1152776
# , mã lỗi: 404
# Lỗi khi crawl trang 1152776
# : HTTP 404
# Không lấy được trang 1130880
# , mã lỗi: 404
# Lỗi khi crawl trang 1130880
# : HTTP 404
# Không lấy được trang 1146646
# , mã lỗi: 404
# Lỗi khi crawl trang 1146646
# : HTTP 404
# Không lấy được trang 1146503
# , mã lỗi: 404
# Lỗi khi crawl trang 1146503
# : HTTP 404
# Không lấy được trang 1151681
# , mã lỗi: 404
# Lỗi khi crawl trang 1151681
# : HTTP 404
# Không lấy được trang 1151503
# , mã lỗi: 404
# Lỗi khi crawl trang 1151503
# : HTTP 404
# Không lấy được trang 1147452
# , mã lỗi: 404
# Lỗi khi crawl trang 1147452
# : HTTP 404
# Không lấy được trang 1153252
# , mã lỗi: 404
# Lỗi khi crawl trang 1153252
# : HTTP 404
# Không lấy được trang 1153119
# , mã lỗi: 404
# Lỗi khi crawl trang 1153119
# : HTTP 404
# Không lấy được trang 1153129
# , mã lỗi: 404
# Lỗi khi crawl trang 1153129
# : HTTP 404
# Không lấy được trang 1152749
# , mã lỗi: 404
# Lỗi khi crawl trang 1152749
# : HTTP 404
# Không lấy được trang 1153774
# , mã lỗi: 404
# Lỗi khi crawl trang 1153774
# : HTTP 404
# Không lấy được trang 1153241
# , mã lỗi: 404
# Lỗi khi crawl trang 1153241
# : HTTP 404
# Không lấy được trang 1153327
# , mã lỗi: 404
# Lỗi khi crawl trang 1153327
# : HTTP 404
# Không lấy được trang 1153661
# , mã lỗi: 404
# Lỗi khi crawl trang 1153661
# : HTTP 404
# Không lấy được trang 1153769
# , mã lỗi: 404
# Lỗi khi crawl trang 1153769
# : HTTP 404
# Không lấy được trang 1152767
# , mã lỗi: 404
# Lỗi khi crawl trang 1152767
# : HTTP 404
# Không lấy được trang 1153006
# , mã lỗi: 404
# Lỗi khi crawl trang 1153006
# : HTTP 404
# Không lấy được trang 1156470
# , mã lỗi: 404
# Lỗi khi crawl trang 1156470
# : HTTP 404
# Không lấy được trang 1153234
# , mã lỗi: 404
# Lỗi khi crawl trang 1153234
# : HTTP 404
# Không lấy được trang 1153031
# , mã lỗi: 404
# Lỗi khi crawl trang 1153031
# : HTTP 404
# Không lấy được trang 1153347
# , mã lỗi: 404
# Lỗi khi crawl trang 1153347
# : HTTP 404
# Không lấy được trang 1156451
# , mã lỗi: 404
# Lỗi khi crawl trang 1156451
# : HTTP 404
# Không lấy được trang 1156691
# , mã lỗi: 404
# Lỗi khi crawl trang 1156691
# : HTTP 404
# Không lấy được trang 1155774
# , mã lỗi: 404
# Lỗi khi crawl trang 1155774
# : HTTP 404
# Không lấy được trang 1156261
# , mã lỗi: 404
# Lỗi khi crawl trang 1156261
# : HTTP 404
# Không lấy được trang 1099833
# , mã lỗi: 404
# Lỗi khi crawl trang 1099833
# : HTTP 404
# Thử lại thất bại cho trang 1099833
# . Lưu ID vào file thất bại.
# Không lấy được trang 1093224
# , mã lỗi: 404
# Lỗi khi crawl trang 1093224
# : HTTP 404
# Thử lại thất bại cho trang 1093224
# . Lưu ID vào file thất bại.
# Không lấy được trang 1099832
# , mã lỗi: 404
# Lỗi khi crawl trang 1099832
# : HTTP 404
# Thử lại thất bại cho trang 1099832
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157589
# , mã lỗi: 404
# Lỗi khi crawl trang 1157589
# : HTTP 404
# Không lấy được trang 1157570
# , mã lỗi: 404
# Lỗi khi crawl trang 1157570
# : HTTP 404
# Không lấy được trang 1113852
# , mã lỗi: 404
# Lỗi khi crawl trang 1113852
# : HTTP 404
# Thử lại thất bại cho trang 1113852
# . Lưu ID vào file thất bại.
# Không lấy được trang 1146824
# , mã lỗi: 404
# Lỗi khi crawl trang 1146824
# : HTTP 404
# Thử lại thất bại cho trang 1146824
# . Lưu ID vào file thất bại.
# Không lấy được trang 1146450
# , mã lỗi: 404
# Lỗi khi crawl trang 1146450
# : HTTP 404
# Thử lại thất bại cho trang 1146450
# . Lưu ID vào file thất bại.
# Không lấy được trang 1142274
# , mã lỗi: 404
# Lỗi khi crawl trang 1142274
# : HTTP 404
# Thử lại thất bại cho trang 1142274
# . Lưu ID vào file thất bại.
# Không lấy được trang 1120971
# , mã lỗi: 404
# Lỗi khi crawl trang 1120971
# : HTTP 404
# Thử lại thất bại cho trang 1120971
# . Lưu ID vào file thất bại.
# Không lấy được trang 1151866
# , mã lỗi: 404
# Lỗi khi crawl trang 1151866
# : HTTP 404
# Thử lại thất bại cho trang 1151866
# . Lưu ID vào file thất bại.
# Không lấy được trang 1108870
# , mã lỗi: 404
# Lỗi khi crawl trang 1108870
# : HTTP 404
# Thử lại thất bại cho trang 1108870
# . Lưu ID vào file thất bại.
# Không lấy được trang 1152250
# , mã lỗi: 404
# Lỗi khi crawl trang 1152250
# : HTTP 404
# Thử lại thất bại cho trang 1152250
# . Lưu ID vào file thất bại.
# Không lấy được trang 1119566
# , mã lỗi: 404
# Lỗi khi crawl trang 1119566
# : HTTP 404
# Thử lại thất bại cho trang 1119566
# . Lưu ID vào file thất bại.
# Không lấy được trang 1150985
# , mã lỗi: 404
# Lỗi khi crawl trang 1150985
# : HTTP 404
# Thử lại thất bại cho trang 1150985
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157219
# , mã lỗi: 404
# Lỗi khi crawl trang 1157219
# : HTTP 404
# Không lấy được trang 1114055
# , mã lỗi: 404
# Lỗi khi crawl trang 1114055
# : HTTP 404
# Thử lại thất bại cho trang 1114055
# . Lưu ID vào file thất bại.
# Không lấy được trang 1108964
# , mã lỗi: 404
# Lỗi khi crawl trang 1108964
# : HTTP 404
# Thử lại thất bại cho trang 1108964
# . Lưu ID vào file thất bại.
# Không lấy được trang 1114100
# , mã lỗi: 404
# Lỗi khi crawl trang 1114100
# : HTTP 404
# Thử lại thất bại cho trang 1114100
# . Lưu ID vào file thất bại.
# Không lấy được trang 1120279
# , mã lỗi: 404
# Lỗi khi crawl trang 1120279
# : HTTP 404
# Thử lại thất bại cho trang 1120279
# . Lưu ID vào file thất bại.
# Không lấy được trang 1140719
# , mã lỗi: 404
# Lỗi khi crawl trang 1140719
# : HTTP 404
# Thử lại thất bại cho trang 1140719
# . Lưu ID vào file thất bại.
# Không lấy được trang 1125653
# , mã lỗi: 404
# Lỗi khi crawl trang 1125653
# : HTTP 404
# Thử lại thất bại cho trang 1125653
# . Lưu ID vào file thất bại.
# Không lấy được trang 1117375
# , mã lỗi: 404
# Lỗi khi crawl trang 1117375
# : HTTP 404
# Thử lại thất bại cho trang 1117375
# . Lưu ID vào file thất bại.
# Không lấy được trang 1120995
# , mã lỗi: 404
# Lỗi khi crawl trang 1120995
# : HTTP 404
# Thử lại thất bại cho trang 1120995
# . Lưu ID vào file thất bại.
# Không lấy được trang 1130686
# , mã lỗi: 404
# Lỗi khi crawl trang 1130686
# : HTTP 404
# Thử lại thất bại cho trang 1130686
# . Lưu ID vào file thất bại.
# Không lấy được trang 1132139
# , mã lỗi: 404
# Lỗi khi crawl trang 1132139
# : HTTP 404
# Thử lại thất bại cho trang 1132139
# . Lưu ID vào file thất bại.
# Không lấy được trang 1125007
# , mã lỗi: 404
# Lỗi khi crawl trang 1125007
# : HTTP 404
# Thử lại thất bại cho trang 1125007
# . Lưu ID vào file thất bại.
# Không lấy được trang 1113992
# , mã lỗi: 404
# Lỗi khi crawl trang 1113992
# : HTTP 404
# Thử lại thất bại cho trang 1113992
# . Lưu ID vào file thất bại.
# Không lấy được trang 1121297
# , mã lỗi: 404
# Lỗi khi crawl trang 1121297
# : HTTP 404
# Thử lại thất bại cho trang 1121297
# . Lưu ID vào file thất bại.
# Không lấy được trang 1124987
# , mã lỗi: 404
# Lỗi khi crawl trang 1124987
# : HTTP 404
# Thử lại thất bại cho trang 1124987
# . Lưu ID vào file thất bại.
# Không lấy được trang 1121808
# , mã lỗi: 404
# Lỗi khi crawl trang 1121808
# : HTTP 404
# Thử lại thất bại cho trang 1121808
# . Lưu ID vào file thất bại.
# Không lấy được trang 1131047
# , mã lỗi: 404
# Lỗi khi crawl trang 1131047
# : HTTP 404
# Thử lại thất bại cho trang 1131047
# . Lưu ID vào file thất bại.
# Không lấy được trang 1132450
# , mã lỗi: 404
# Lỗi khi crawl trang 1132450
# : HTTP 404
# Thử lại thất bại cho trang 1132450
# . Lưu ID vào file thất bại.
# Không lấy được trang 1125652
# , mã lỗi: 404
# Lỗi khi crawl trang 1125652
# : HTTP 404
# Thử lại thất bại cho trang 1125652
# . Lưu ID vào file thất bại.
# Không lấy được trang 1134155
# , mã lỗi: 404
# Lỗi khi crawl trang 1134155
# : HTTP 404
# Thử lại thất bại cho trang 1134155
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156959
# , mã lỗi: 404
# Lỗi khi crawl trang 1156959
# : HTTP 404
# Không lấy được trang 1133240
# , mã lỗi: 404
# Lỗi khi crawl trang 1133240
# : HTTP 404
# Thử lại thất bại cho trang 1133240
# . Lưu ID vào file thất bại.
# Không lấy được trang 1130262
# , mã lỗi: 404
# Lỗi khi crawl trang 1130262
# : HTTP 404
# Thử lại thất bại cho trang 1130262
# . Lưu ID vào file thất bại.
# Không lấy được trang 1120969
# , mã lỗi: 404
# Lỗi khi crawl trang 1120969
# : HTTP 404
# Thử lại thất bại cho trang 1120969
# . Lưu ID vào file thất bại.
# Không lấy được trang 1130266
# , mã lỗi: 404
# Lỗi khi crawl trang 1130266
# : HTTP 404
# Thử lại thất bại cho trang 1130266
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157397
# , mã lỗi: 404
# Lỗi khi crawl trang 1157397
# : HTTP 404
# Không lấy được trang 1157680
# , mã lỗi: 404
# Lỗi khi crawl trang 1157680
# : HTTP 404
# Không lấy được trang 1157375
# , mã lỗi: 404
# Lỗi khi crawl trang 1157375
# : HTTP 404
# Không lấy được trang 1156956
# , mã lỗi: 404
# Lỗi khi crawl trang 1156956
# : HTTP 404
# Không lấy được trang 1124998
# , mã lỗi: 404
# Lỗi khi crawl trang 1124998
# : HTTP 404
# Thử lại thất bại cho trang 1124998
# . Lưu ID vào file thất bại.
# Không lấy được trang 1121797
# , mã lỗi: 404
# Lỗi khi crawl trang 1121797
# : HTTP 404
# Thử lại thất bại cho trang 1121797
# . Lưu ID vào file thất bại.
# Không lấy được trang 1152776
# , mã lỗi: 404
# Lỗi khi crawl trang 1152776
# : HTTP 404
# Thử lại thất bại cho trang 1152776
# . Lưu ID vào file thất bại.
# Không lấy được trang 1130880
# , mã lỗi: 404
# Lỗi khi crawl trang 1130880
# : HTTP 404
# Thử lại thất bại cho trang 1130880
# . Lưu ID vào file thất bại.
# Không lấy được trang 1146646
# , mã lỗi: 404
# Lỗi khi crawl trang 1146646
# : HTTP 404
# Thử lại thất bại cho trang 1146646
# . Lưu ID vào file thất bại.
# Không lấy được trang 1146503
# , mã lỗi: 404
# Lỗi khi crawl trang 1146503
# : HTTP 404
# Thử lại thất bại cho trang 1146503
# . Lưu ID vào file thất bại.
# Không lấy được trang 1151681
# , mã lỗi: 404
# Lỗi khi crawl trang 1151681
# : HTTP 404
# Thử lại thất bại cho trang 1151681
# . Lưu ID vào file thất bại.
# Không lấy được trang 1151503
# , mã lỗi: 404
# Lỗi khi crawl trang 1151503
# : HTTP 404
# Thử lại thất bại cho trang 1151503
# . Lưu ID vào file thất bại.
# Không lấy được trang 1147452
# , mã lỗi: 404
# Lỗi khi crawl trang 1147452
# : HTTP 404
# Thử lại thất bại cho trang 1147452
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153252
# , mã lỗi: 404
# Lỗi khi crawl trang 1153252
# : HTTP 404
# Thử lại thất bại cho trang 1153252
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153119
# , mã lỗi: 404
# Lỗi khi crawl trang 1153119
# : HTTP 404
# Thử lại thất bại cho trang 1153119
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153129
# , mã lỗi: 404
# Lỗi khi crawl trang 1153129
# : HTTP 404
# Thử lại thất bại cho trang 1153129
# . Lưu ID vào file thất bại.
# Không lấy được trang 1152749
# , mã lỗi: 404
# Lỗi khi crawl trang 1152749
# : HTTP 404
# Thử lại thất bại cho trang 1152749
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153774
# , mã lỗi: 404
# Lỗi khi crawl trang 1153774
# : HTTP 404
# Thử lại thất bại cho trang 1153774
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153241
# , mã lỗi: 404
# Lỗi khi crawl trang 1153241
# : HTTP 404
# Thử lại thất bại cho trang 1153241
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153327
# , mã lỗi: 404
# Lỗi khi crawl trang 1153327
# : HTTP 404
# Thử lại thất bại cho trang 1153327
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153661
# , mã lỗi: 404
# Lỗi khi crawl trang 1153661
# : HTTP 404
# Thử lại thất bại cho trang 1153661
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153769
# , mã lỗi: 404
# Lỗi khi crawl trang 1153769
# : HTTP 404
# Thử lại thất bại cho trang 1153769
# . Lưu ID vào file thất bại.
# Không lấy được trang 1152767
# , mã lỗi: 404
# Lỗi khi crawl trang 1152767
# : HTTP 404
# Thử lại thất bại cho trang 1152767
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153006
# , mã lỗi: 404
# Lỗi khi crawl trang 1153006
# : HTTP 404
# Thử lại thất bại cho trang 1153006
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156470
# , mã lỗi: 404
# Lỗi khi crawl trang 1156470
# : HTTP 404
# Thử lại thất bại cho trang 1156470
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153234
# , mã lỗi: 404
# Lỗi khi crawl trang 1153234
# : HTTP 404
# Thử lại thất bại cho trang 1153234
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153031
# , mã lỗi: 404
# Lỗi khi crawl trang 1153031
# : HTTP 404
# Thử lại thất bại cho trang 1153031
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153347
# , mã lỗi: 404
# Lỗi khi crawl trang 1153347
# : HTTP 404
# Thử lại thất bại cho trang 1153347
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156451
# , mã lỗi: 404
# Lỗi khi crawl trang 1156451
# : HTTP 404
# Thử lại thất bại cho trang 1156451
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156691
# , mã lỗi: 404
# Lỗi khi crawl trang 1156691
# : HTTP 404
# Thử lại thất bại cho trang 1156691
# . Lưu ID vào file thất bại.
# Không lấy được trang 1155774
# , mã lỗi: 404
# Lỗi khi crawl trang 1155774
# : HTTP 404
# Thử lại thất bại cho trang 1155774
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156261
# , mã lỗi: 404
# Lỗi khi crawl trang 1156261
# : HTTP 404
# Thử lại thất bại cho trang 1156261
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157589
# , mã lỗi: 404
# Lỗi khi crawl trang 1157589
# : HTTP 404
# Thử lại thất bại cho trang 1157589
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157570
# , mã lỗi: 404
# Lỗi khi crawl trang 1157570
# : HTTP 404
# Thử lại thất bại cho trang 1157570
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157219
# , mã lỗi: 404
# Lỗi khi crawl trang 1157219
# : HTTP 404
# Thử lại thất bại cho trang 1157219
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156959
# , mã lỗi: 404
# Lỗi khi crawl trang 1156959
# : HTTP 404
# Không lấy được trang 1157397
# , mã lỗi: 404
# Lỗi khi crawl trang 1157397
# : HTTP 404
# Thử lại thất bại cho trang 1157397
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157680
# , mã lỗi: 404
# Lỗi khi crawl trang 1157680
# : HTTP 404
# Thử lại thất bại cho trang 1157680
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157375
# , mã lỗi: 404
# Lỗi khi crawl trang 1157375
# : HTTP 404
# Thử lại thất bại cho trang 1157375
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156956
# , mã lỗi: 404
# Lỗi khi crawl trang 1156956
# : HTTP 404
# Thử lại thất bại cho trang 1156956
# . Lưu ID vào file thất bại.
# Không lấy được trang 1156959
# , mã lỗi: 404
# Lỗi khi crawl trang 1156959
# : HTTP 404
# Thử lại thất bại cho trang 1156959
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153812
# , mã lỗi: 404
# Lỗi khi crawl trang 1153812
# : HTTP 404
# Không lấy được trang 1155220
# , mã lỗi: 404
# Lỗi khi crawl trang 1155220
# : HTTP 404
# Không lấy được trang 1155083
# , mã lỗi: 404
# Lỗi khi crawl trang 1155083
# : HTTP 404
# Không lấy được trang 1154185
# , mã lỗi: 404
# Lỗi khi crawl trang 1154185
# : HTTP 404
# Không lấy được trang 1153659
# , mã lỗi: 404
# Lỗi khi crawl trang 1153659
# : HTTP 404
# Không lấy được trang 1153898
# , mã lỗi: 404
# Lỗi khi crawl trang 1153898
# : HTTP 404
# Không lấy được trang 1154187
# , mã lỗi: 404
# Lỗi khi crawl trang 1154187
# : HTTP 404
# Không lấy được trang 1153621
# , mã lỗi: 404
# Lỗi khi crawl trang 1153621
# : HTTP 404
# Không lấy được trang 1153894
# , mã lỗi: 404
# Lỗi khi crawl trang 1153894
# : HTTP 404
# Không lấy được trang 1153810
# , mã lỗi: 404
# Lỗi khi crawl trang 1153810
# : HTTP 404
# Không lấy được trang 1154217
# , mã lỗi: 404
# Lỗi khi crawl trang 1154217
# : HTTP 404
# Không lấy được trang 1153818
# , mã lỗi: 404
# Lỗi khi crawl trang 1153818
# : HTTP 404
# Không lấy được trang 1155223
# , mã lỗi: 404
# Lỗi khi crawl trang 1155223
# : HTTP 404
# Không lấy được trang 1153771
# , mã lỗi: 404
# Lỗi khi crawl trang 1153771
# : HTTP 404
# Không lấy được trang 1154184
# , mã lỗi: 404
# Lỗi khi crawl trang 1154184
# : HTTP 404
# Không lấy được trang 1153981
# , mã lỗi: 404
# Lỗi khi crawl trang 1153981
# : HTTP 404
# Không lấy được trang 1154215
# , mã lỗi: 404
# Lỗi khi crawl trang 1154215
# : HTTP 404
# Không lấy được trang 1155081
# , mã lỗi: 404
# Lỗi khi crawl trang 1155081
# : HTTP 404
# Không lấy được trang 1155221
# , mã lỗi: 404
# Lỗi khi crawl trang 1155221
# : HTTP 404
# Không lấy được trang 1158194
# , mã lỗi: 404
# Lỗi khi crawl trang 1158194
# : HTTP 404
# Không lấy được trang 1157648
# , mã lỗi: 404
# Lỗi khi crawl trang 1157648
# : HTTP 404
# Không lấy được trang 1157374
# , mã lỗi: 404
# Lỗi khi crawl trang 1157374
# : HTTP 404
# Không lấy được trang 1163796
# , mã lỗi: 404
# Lỗi khi crawl trang 1163796
# : HTTP 404
# Không lấy được trang 1162539
# , mã lỗi: 404
# Lỗi khi crawl trang 1162539
# : HTTP 404
# Không lấy được trang 1160596
# , mã lỗi: 404
# Lỗi khi crawl trang 1160596
# : HTTP 404
# Không lấy được trang 1163010
# , mã lỗi: 404
# Lỗi khi crawl trang 1163010
# : HTTP 404
# Không lấy được trang 1160628
# , mã lỗi: 404
# Lỗi khi crawl trang 1160628
# : HTTP 404
# Không lấy được trang 1157065
# , mã lỗi: 404
# Lỗi khi crawl trang 1157065
# : HTTP 404
# Không lấy được trang 1157061
# , mã lỗi: 404
# Lỗi khi crawl trang 1157061
# : HTTP 404
# Không lấy được trang 1161468
# , mã lỗi: 404
# Lỗi khi crawl trang 1161468
# : HTTP 404
# Không lấy được trang 1163798
# , mã lỗi: 404
# Lỗi khi crawl trang 1163798
# : HTTP 404
# Không lấy được trang 1183647
# , mã lỗi: 404
# Lỗi khi crawl trang 1183647
# : HTTP 404
# Không lấy được trang 1164405
# , mã lỗi: 404
# Lỗi khi crawl trang 1164405
# : HTTP 404
# Không lấy được trang 1157067
# , mã lỗi: 404
# Lỗi khi crawl trang 1157067
# : HTTP 404
# Không lấy được trang 1183501
# , mã lỗi: 404
# Lỗi khi crawl trang 1183501
# : HTTP 404
# Không lấy được trang 1183779
# , mã lỗi: 404
# Lỗi khi crawl trang 1183779
# : HTTP 404
# Không lấy được trang 1183829
# , mã lỗi: 404
# Lỗi khi crawl trang 1183829
# : HTTP 404
# Không lấy được trang 1183508
# , mã lỗi: 404
# Lỗi khi crawl trang 1183508
# : HTTP 404
# Không lấy được trang 1184152
# , mã lỗi: 404
# Lỗi khi crawl trang 1184152
# : HTTP 404
# Không lấy được trang 1184209
# , mã lỗi: 404
# Lỗi khi crawl trang 1184209
# : HTTP 404
# Không lấy được trang 1183444
# , mã lỗi: 404
# Lỗi khi crawl trang 1183444
# : HTTP 404
# Không lấy được trang 1183764
# , mã lỗi: 404
# Lỗi khi crawl trang 1183764
# : HTTP 404
# Không lấy được trang 1184185
# , mã lỗi: 404
# Lỗi khi crawl trang 1184185
# : HTTP 404
# Không lấy được trang 1183758
# , mã lỗi: 404
# Lỗi khi crawl trang 1183758
# : HTTP 404
# Không lấy được trang 1184124
# , mã lỗi: 404
# Lỗi khi crawl trang 1184124
# : HTTP 404
# Không lấy được trang 1183749
# , mã lỗi: 404
# Lỗi khi crawl trang 1183749
# : HTTP 404
# Không lấy được trang 1183970
# , mã lỗi: 404
# Lỗi khi crawl trang 1183970
# : HTTP 404
# Không lấy được trang 1184262
# , mã lỗi: 404
# Lỗi khi crawl trang 1184262
# : HTTP 404
# Không lấy được trang 1183624
# , mã lỗi: 404
# Lỗi khi crawl trang 1183624
# : HTTP 404
# Không lấy được trang 1184848
# , mã lỗi: 404
# Lỗi khi crawl trang 1184848
# : HTTP 404
# Không lấy được trang 1183973
# , mã lỗi: 404
# Lỗi khi crawl trang 1183973
# : HTTP 404
# Không lấy được trang 1175038
# , mã lỗi: 404
# Lỗi khi crawl trang 1175038
# : HTTP 404
# Không lấy được trang 1181845
# , mã lỗi: 404
# Lỗi khi crawl trang 1181845
# : HTTP 404
# Không lấy được trang 1180731
# , mã lỗi: 404
# Lỗi khi crawl trang 1180731
# : HTTP 404
# Không lấy được trang 1180246
# , mã lỗi: 404
# Lỗi khi crawl trang 1180246
# : HTTP 404
# Không lấy được trang 1181207
# , mã lỗi: 404
# Lỗi khi crawl trang 1181207
# : HTTP 404
# Không lấy được trang 1180458
# , mã lỗi: 404
# Lỗi khi crawl trang 1180458
# : HTTP 404
# Không lấy được trang 1181633
# , mã lỗi: 404
# Lỗi khi crawl trang 1181633
# : HTTP 404
# Không lấy được trang 1181577
# , mã lỗi: 404
# Lỗi khi crawl trang 1181577
# : HTTP 404
# Không lấy được trang 1182197
# , mã lỗi: 404
# Lỗi khi crawl trang 1182197
# : HTTP 404
# Không lấy được trang 1181199
# , mã lỗi: 404
# Lỗi khi crawl trang 1181199
# : HTTP 404
# Không lấy được trang 1181011
# , mã lỗi: 404
# Lỗi khi crawl trang 1181011
# : HTTP 404
# Không lấy được trang 1180279
# , mã lỗi: 404
# Lỗi khi crawl trang 1180279
# : HTTP 404
# Không lấy được trang 1181760
# , mã lỗi: 404
# Lỗi khi crawl trang 1181760
# : HTTP 404
# Không lấy được trang 1181538
# , mã lỗi: 404
# Lỗi khi crawl trang 1181538
# : HTTP 404
# Không lấy được trang 1166793
# , mã lỗi: 404
# Lỗi khi crawl trang 1166793
# : HTTP 404
# Không lấy được trang 1170533
# , mã lỗi: 404
# Lỗi khi crawl trang 1170533
# : HTTP 404
# Không lấy được trang 1172971
# , mã lỗi: 404
# Lỗi khi crawl trang 1172971
# : HTTP 404
# Không lấy được trang 1172919
# , mã lỗi: 404
# Lỗi khi crawl trang 1172919
# : HTTP 404
# Không lấy được trang 1181973
# , mã lỗi: 404
# Lỗi khi crawl trang 1181973
# : HTTP 404
# Không lấy được trang 1181591
# , mã lỗi: 404
# Lỗi khi crawl trang 1181591
# : HTTP 404
# Không lấy được trang 1176453
# , mã lỗi: 404
# Lỗi khi crawl trang 1176453
# : HTTP 404
# Không lấy được trang 1178244
# , mã lỗi: 404
# Lỗi khi crawl trang 1178244
# : HTTP 404
# Không lấy được trang 1178459
# , mã lỗi: 404
# Lỗi khi crawl trang 1178459
# : HTTP 404
# Không lấy được trang 1182150
# , mã lỗi: 404
# Lỗi khi crawl trang 1182150
# : HTTP 404
# Không lấy được trang 1181135
# , mã lỗi: 404
# Lỗi khi crawl trang 1181135
# : HTTP 404
# Không lấy được trang 1180727
# , mã lỗi: 404
# Lỗi khi crawl trang 1180727
# : HTTP 404
# Không lấy được trang 1181821
# , mã lỗi: 404
# Lỗi khi crawl trang 1181821
# : HTTP 404
# Không lấy được trang 1180663
# , mã lỗi: 404
# Lỗi khi crawl trang 1180663
# : HTTP 404
# Không lấy được trang 1174924
# , mã lỗi: 404
# Lỗi khi crawl trang 1174924
# : HTTP 404
# Không lấy được trang 1180130
# , mã lỗi: 404
# Lỗi khi crawl trang 1180130
# : HTTP 404
# Không lấy được trang 1181425
# , mã lỗi: 404
# Lỗi khi crawl trang 1181425
# : HTTP 404
# Không lấy được trang 1184212
# , mã lỗi: 404
# Lỗi khi crawl trang 1184212
# : HTTP 404
# Không lấy được trang 1168148
# , mã lỗi: 404
# Lỗi khi crawl trang 1168148
# : HTTP 404
# Không lấy được trang 1182060
# , mã lỗi: 404
# Lỗi khi crawl trang 1182060
# : HTTP 404
# Không lấy được trang 1182199
# , mã lỗi: 404
# Lỗi khi crawl trang 1182199
# : HTTP 404
# Không lấy được trang 1181590
# , mã lỗi: 404
# Lỗi khi crawl trang 1181590
# : HTTP 404
# Không lấy được trang 1180333
# , mã lỗi: 404
# Lỗi khi crawl trang 1180333
# : HTTP 404
# Không lấy được trang 1181565
# , mã lỗi: 404
# Lỗi khi crawl trang 1181565
# : HTTP 404
# Không lấy được trang 1179019
# , mã lỗi: 404
# Lỗi khi crawl trang 1179019
# : HTTP 404
# Không lấy được trang 1181823
# , mã lỗi: 404
# Lỗi khi crawl trang 1181823
# : HTTP 404
# Không lấy được trang 1179974
# , mã lỗi: 404
# Lỗi khi crawl trang 1179974
# : HTTP 404
# Không lấy được trang 1182349
# , mã lỗi: 404
# Lỗi khi crawl trang 1182349
# : HTTP 404
# Không lấy được trang 1153812
# , mã lỗi: 404
# Lỗi khi crawl trang 1153812
# : HTTP 404
# Thử lại thất bại cho trang 1153812
# . Lưu ID vào file thất bại.
# Không lấy được trang 1155220
# , mã lỗi: 404
# Lỗi khi crawl trang 1155220
# : HTTP 404
# Thử lại thất bại cho trang 1155220
# . Lưu ID vào file thất bại.
# Không lấy được trang 1155083
# , mã lỗi: 404
# Lỗi khi crawl trang 1155083
# : HTTP 404
# Thử lại thất bại cho trang 1155083
# . Lưu ID vào file thất bại.
# Không lấy được trang 1175461
# , mã lỗi: 404
# Lỗi khi crawl trang 1175461
# : HTTP 404
# Không lấy được trang 1154185
# , mã lỗi: 404
# Lỗi khi crawl trang 1154185
# : HTTP 404
# Thử lại thất bại cho trang 1154185
# . Lưu ID vào file thất bại.
# Không lấy được trang 1154187
# , mã lỗi: 404
# Lỗi khi crawl trang 1154187
# : HTTP 404
# Thử lại thất bại cho trang 1154187
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153659
# , mã lỗi: 404
# Lỗi khi crawl trang 1153659
# : HTTP 404
# Thử lại thất bại cho trang 1153659
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153898
# , mã lỗi: 404
# Lỗi khi crawl trang 1153898
# : HTTP 404
# Thử lại thất bại cho trang 1153898
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153621
# , mã lỗi: 404
# Lỗi khi crawl trang 1153621
# : HTTP 404
# Thử lại thất bại cho trang 1153621
# . Lưu ID vào file thất bại.
# Không lấy được trang 1154217
# , mã lỗi: 404
# Lỗi khi crawl trang 1154217
# : HTTP 404
# Thử lại thất bại cho trang 1154217
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153771
# , mã lỗi: 404
# Lỗi khi crawl trang 1153771
# : HTTP 404
# Thử lại thất bại cho trang 1153771
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153810
# , mã lỗi: 404
# Lỗi khi crawl trang 1153810
# : HTTP 404
# Thử lại thất bại cho trang 1153810
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153894
# , mã lỗi: 404
# Lỗi khi crawl trang 1153894
# : HTTP 404
# Thử lại thất bại cho trang 1153894
# . Lưu ID vào file thất bại.
# Không lấy được trang 1154184
# , mã lỗi: 404
# Lỗi khi crawl trang 1154184
# : HTTP 404
# Thử lại thất bại cho trang 1154184
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153818
# , mã lỗi: 404
# Lỗi khi crawl trang 1153818
# : HTTP 404
# Thử lại thất bại cho trang 1153818
# . Lưu ID vào file thất bại.
# Không lấy được trang 1154215
# , mã lỗi: 404
# Lỗi khi crawl trang 1154215
# : HTTP 404
# Thử lại thất bại cho trang 1154215
# . Lưu ID vào file thất bại.
# Không lấy được trang 1155223
# , mã lỗi: 404
# Lỗi khi crawl trang 1155223
# : HTTP 404
# Thử lại thất bại cho trang 1155223
# . Lưu ID vào file thất bại.
# Không lấy được trang 1153981
# , mã lỗi: 404
# Lỗi khi crawl trang 1153981
# : HTTP 404
# Thử lại thất bại cho trang 1153981
# . Lưu ID vào file thất bại.
# Không lấy được trang 1155081
# , mã lỗi: 404
# Lỗi khi crawl trang 1155081
# : HTTP 404
# Thử lại thất bại cho trang 1155081
# . Lưu ID vào file thất bại.
# Không lấy được trang 1157648
# , mã lỗi: 404
# Lỗi khi crawl trang 1157648
# : HTTP 404
# Thử lại thất bại cho trang 1157648
# . Lưu ID vào file thất bại.
# Không lấy được trang 1155221
# , mã lỗi: 404
# Lỗi khi crawl trang 1155221
# : HTTP 404
# Thử lại thất bại cho trang 1155221
# . Lưu ID vào file thất bại.
# Không lấy được trang 1158194
# , mã lỗi: 404
# Lỗi khi crawl trang 1158194
# : HTTP 404
# Thử lại thất bại cho trang 1158194
# . Lưu ID vào file thất bại.
# ...
# , mã lỗi: 404
# Lỗi khi crawl trang 1183829
# : HTTP 404
# Thử lại thất bại cho trang 1183829
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184209
# , mã lỗi: 404
# Lỗi khi crawl trang 1184209
# : HTTP 404
# Thử lại thất bại cho trang 1184209
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183758
# , mã lỗi: 404
# Lỗi khi crawl trang 1183758
# : HTTP 404
# Thử lại thất bại cho trang 1183758
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183444
# , mã lỗi: 404
# Lỗi khi crawl trang 1183444
# : HTTP 404
# Thử lại thất bại cho trang 1183444
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183749
# , mã lỗi: 404
# Lỗi khi crawl trang 1183749
# : HTTP 404
# Thử lại thất bại cho trang 1183749
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184185
# , mã lỗi: 404
# Lỗi khi crawl trang 1184185
# : HTTP 404
# Thử lại thất bại cho trang 1184185
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183764
# , mã lỗi: 404
# Lỗi khi crawl trang 1183764
# : HTTP 404
# Thử lại thất bại cho trang 1183764
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184124
# , mã lỗi: 404
# Lỗi khi crawl trang 1184124
# : HTTP 404
# Thử lại thất bại cho trang 1184124
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184262
# , mã lỗi: 404
# Lỗi khi crawl trang 1184262
# : HTTP 404
# Thử lại thất bại cho trang 1184262
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183624
# , mã lỗi: 404
# Lỗi khi crawl trang 1183624
# : HTTP 404
# Thử lại thất bại cho trang 1183624
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180731
# , mã lỗi: 404
# Lỗi khi crawl trang 1180731
# : HTTP 404
# Thử lại thất bại cho trang 1180731
# . Lưu ID vào file thất bại.
# Không lấy được trang 1175038
# , mã lỗi: 404
# Lỗi khi crawl trang 1175038
# : HTTP 404
# Thử lại thất bại cho trang 1175038
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183970
# , mã lỗi: 404
# Lỗi khi crawl trang 1183970
# : HTTP 404
# Thử lại thất bại cho trang 1183970
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180246
# , mã lỗi: 404
# Lỗi khi crawl trang 1180246
# : HTTP 404
# Thử lại thất bại cho trang 1180246
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184848
# , mã lỗi: 404
# Lỗi khi crawl trang 1184848
# : HTTP 404
# Thử lại thất bại cho trang 1184848
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183973
# , mã lỗi: 404
# Lỗi khi crawl trang 1183973
# : HTTP 404
# Thử lại thất bại cho trang 1183973
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180458
# , mã lỗi: 404
# Lỗi khi crawl trang 1180458
# : HTTP 404
# Thử lại thất bại cho trang 1180458
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181845
# , mã lỗi: 404
# Lỗi khi crawl trang 1181845
# : HTTP 404
# Thử lại thất bại cho trang 1181845
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181207
# , mã lỗi: 404
# Lỗi khi crawl trang 1181207
# : HTTP 404
# Thử lại thất bại cho trang 1181207
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181633
# , mã lỗi: 404
# Lỗi khi crawl trang 1181633
# : HTTP 404
# Thử lại thất bại cho trang 1181633
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181199
# , mã lỗi: 404
# Lỗi khi crawl trang 1181199
# : HTTP 404
# Thử lại thất bại cho trang 1181199
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181577
# , mã lỗi: 404
# Lỗi khi crawl trang 1181577
# : HTTP 404
# Thử lại thất bại cho trang 1181577
# . Lưu ID vào file thất bại.
# Không lấy được trang 1182197
# , mã lỗi: 404
# Lỗi khi crawl trang 1182197
# : HTTP 404
# Thử lại thất bại cho trang 1182197
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181011
# , mã lỗi: 404
# Lỗi khi crawl trang 1181011
# : HTTP 404
# Thử lại thất bại cho trang 1181011
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180279
# , mã lỗi: 404
# Lỗi khi crawl trang 1180279
# : HTTP 404
# Thử lại thất bại cho trang 1180279
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181760
# , mã lỗi: 404
# Lỗi khi crawl trang 1181760
# : HTTP 404
# Thử lại thất bại cho trang 1181760
# . Lưu ID vào file thất bại.
# Không lấy được trang 1166793
# , mã lỗi: 404
# Lỗi khi crawl trang 1166793
# : HTTP 404
# Thử lại thất bại cho trang 1166793
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181538
# , mã lỗi: 404
# Lỗi khi crawl trang 1181538
# : HTTP 404
# Thử lại thất bại cho trang 1181538
# . Lưu ID vào file thất bại.
# Không lấy được trang 1170533
# , mã lỗi: 404
# Lỗi khi crawl trang 1170533
# : HTTP 404
# Thử lại thất bại cho trang 1170533
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181973
# , mã lỗi: 404
# Lỗi khi crawl trang 1181973
# : HTTP 404
# Thử lại thất bại cho trang 1181973
# . Lưu ID vào file thất bại.
# Không lấy được trang 1172971
# , mã lỗi: 404
# Lỗi khi crawl trang 1172971
# : HTTP 404
# Thử lại thất bại cho trang 1172971
# . Lưu ID vào file thất bại.
# Không lấy được trang 1172919
# , mã lỗi: 404
# Lỗi khi crawl trang 1172919
# : HTTP 404
# Thử lại thất bại cho trang 1172919
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181591
# , mã lỗi: 404
# Lỗi khi crawl trang 1181591
# : HTTP 404
# Thử lại thất bại cho trang 1181591
# . Lưu ID vào file thất bại.
# Không lấy được trang 1178244
# , mã lỗi: 404
# Lỗi khi crawl trang 1178244
# : HTTP 404
# Thử lại thất bại cho trang 1178244
# . Lưu ID vào file thất bại.
# Không lấy được trang 1176453
# , mã lỗi: 404
# Lỗi khi crawl trang 1176453
# : HTTP 404
# Thử lại thất bại cho trang 1176453
# . Lưu ID vào file thất bại.
# Không lấy được trang 1178459
# , mã lỗi: 404
# Lỗi khi crawl trang 1178459
# : HTTP 404
# Thử lại thất bại cho trang 1178459
# . Lưu ID vào file thất bại.
# Không lấy được trang 1182150
# , mã lỗi: 404
# Lỗi khi crawl trang 1182150
# : HTTP 404
# Thử lại thất bại cho trang 1182150
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180727
# , mã lỗi: 404
# Lỗi khi crawl trang 1180727
# : HTTP 404
# Thử lại thất bại cho trang 1180727
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181821
# , mã lỗi: 404
# Lỗi khi crawl trang 1181821
# : HTTP 404
# Thử lại thất bại cho trang 1181821
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181135
# , mã lỗi: 404
# Lỗi khi crawl trang 1181135
# : HTTP 404
# Thử lại thất bại cho trang 1181135
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180130
# , mã lỗi: 404
# Lỗi khi crawl trang 1180130
# : HTTP 404
# Thử lại thất bại cho trang 1180130
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184212
# , mã lỗi: 404
# Lỗi khi crawl trang 1184212
# : HTTP 404
# Thử lại thất bại cho trang 1184212
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180663
# , mã lỗi: 404
# Lỗi khi crawl trang 1180663
# : HTTP 404
# Thử lại thất bại cho trang 1180663
# . Lưu ID vào file thất bại.
# Không lấy được trang 1174924
# , mã lỗi: 404
# Lỗi khi crawl trang 1174924
# : HTTP 404
# Thử lại thất bại cho trang 1174924
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181425
# , mã lỗi: 404
# Lỗi khi crawl trang 1181425
# : HTTP 404
# Thử lại thất bại cho trang 1181425
# . Lưu ID vào file thất bại.
# Không lấy được trang 1168148
# , mã lỗi: 404
# Lỗi khi crawl trang 1168148
# : HTTP 404
# Thử lại thất bại cho trang 1168148
# . Lưu ID vào file thất bại.
# Không lấy được trang 1182060
# , mã lỗi: 404
# Lỗi khi crawl trang 1182060
# : HTTP 404
# Thử lại thất bại cho trang 1182060
# . Lưu ID vào file thất bại.
# Không lấy được trang 1182199
# , mã lỗi: 404
# Lỗi khi crawl trang 1182199
# : HTTP 404
# Thử lại thất bại cho trang 1182199
# . Lưu ID vào file thất bại.
# Không lấy được trang 1180333
# , mã lỗi: 404
# Lỗi khi crawl trang 1180333
# : HTTP 404
# Thử lại thất bại cho trang 1180333
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181590
# , mã lỗi: 404
# Lỗi khi crawl trang 1181590
# : HTTP 404
# Thử lại thất bại cho trang 1181590
# . Lưu ID vào file thất bại.
# Không lấy được trang 1179019
# , mã lỗi: 404
# Lỗi khi crawl trang 1179019
# : HTTP 404
# Thử lại thất bại cho trang 1179019
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181565
# , mã lỗi: 404
# Lỗi khi crawl trang 1181565
# : HTTP 404
# Thử lại thất bại cho trang 1181565
# . Lưu ID vào file thất bại.
# Không lấy được trang 1179974
# , mã lỗi: 404
# Lỗi khi crawl trang 1179974
# : HTTP 404
# Thử lại thất bại cho trang 1179974
# . Lưu ID vào file thất bại.
# Không lấy được trang 1182349
# , mã lỗi: 404
# Lỗi khi crawl trang 1182349
# : HTTP 404
# Thử lại thất bại cho trang 1182349
# . Lưu ID vào file thất bại.
# Không lấy được trang 1181823
# , mã lỗi: 404
# Lỗi khi crawl trang 1181823
# : HTTP 404
# Thử lại thất bại cho trang 1181823
# . Lưu ID vào file thất bại.
# Không lấy được trang 1175461
# , mã lỗi: 404
# Lỗi khi crawl trang 1175461
# : HTTP 404
# Thử lại thất bại cho trang 1175461
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184719
# , mã lỗi: 404
# Lỗi khi crawl trang 1184719
# : HTTP 404
# Thử lại thất bại cho trang 1184719
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183142
# , mã lỗi: 404
# Lỗi khi crawl trang 1183142
# : HTTP 404
# Thử lại thất bại cho trang 1183142
# . Lưu ID vào file thất bại.
# Không lấy được trang 1182935
# , mã lỗi: 404
# Lỗi khi crawl trang 1182935
# : HTTP 404
# Thử lại thất bại cho trang 1182935
# . Lưu ID vào file thất bại.
# Không lấy được trang 1183338
# , mã lỗi: 404
# Lỗi khi crawl trang 1183338
# : HTTP 404
# Thử lại thất bại cho trang 1183338
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185209
# , mã lỗi: 404
# Lỗi khi crawl trang 1185209
# : HTTP 404
# Thử lại thất bại cho trang 1185209
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185089
# , mã lỗi: 404
# Lỗi khi crawl trang 1185089
# : HTTP 404
# Thử lại thất bại cho trang 1185089
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185113
# , mã lỗi: 404
# Lỗi khi crawl trang 1185113
# : HTTP 404
# Thử lại thất bại cho trang 1185113
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185067
# , mã lỗi: 404
# Lỗi khi crawl trang 1185067
# : HTTP 404
# Thử lại thất bại cho trang 1185067
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185210
# , mã lỗi: 404
# Lỗi khi crawl trang 1185210
# : HTTP 404
# Thử lại thất bại cho trang 1185210
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185008
# , mã lỗi: 404
# Lỗi khi crawl trang 1185008
# : HTTP 404
# Thử lại thất bại cho trang 1185008
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185049
# , mã lỗi: 404
# Lỗi khi crawl trang 1185049
# : HTTP 404
# Thử lại thất bại cho trang 1185049
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185066
# , mã lỗi: 404
# Lỗi khi crawl trang 1185066
# : HTTP 404
# Thử lại thất bại cho trang 1185066
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184147
# , mã lỗi: 404
# Lỗi khi crawl trang 1184147
# : HTTP 404
# Thử lại thất bại cho trang 1184147
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185090
# , mã lỗi: 404
# Lỗi khi crawl trang 1185090
# : HTTP 404
# Thử lại thất bại cho trang 1185090
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185071
# , mã lỗi: 404
# Lỗi khi crawl trang 1185071
# : HTTP 404
# Thử lại thất bại cho trang 1185071
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185186
# , mã lỗi: 404
# Lỗi khi crawl trang 1185186
# : HTTP 404
# Thử lại thất bại cho trang 1185186
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185247
# , mã lỗi: 404
# Lỗi khi crawl trang 1185247
# : HTTP 404
# Thử lại thất bại cho trang 1185247
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185055
# , mã lỗi: 404
# Lỗi khi crawl trang 1185055
# : HTTP 404
# Thử lại thất bại cho trang 1185055
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185092
# , mã lỗi: 404
# Lỗi khi crawl trang 1185092
# : HTTP 404
# Thử lại thất bại cho trang 1185092
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184745
# , mã lỗi: 404
# Lỗi khi crawl trang 1184745
# : HTTP 404
# Thử lại thất bại cho trang 1184745
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184225
# , mã lỗi: 404
# Lỗi khi crawl trang 1184225
# : HTTP 404
# Thử lại thất bại cho trang 1184225
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185276
# , mã lỗi: 404
# Lỗi khi crawl trang 1185276
# : HTTP 404
# Thử lại thất bại cho trang 1185276
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184767
# , mã lỗi: 404
# Lỗi khi crawl trang 1184767
# : HTTP 404
# Thử lại thất bại cho trang 1184767
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184636
# , mã lỗi: 404
# Lỗi khi crawl trang 1184636
# : HTTP 404
# Thử lại thất bại cho trang 1184636
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184770
# , mã lỗi: 404
# Lỗi khi crawl trang 1184770
# : HTTP 404
# Thử lại thất bại cho trang 1184770
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184773
# , mã lỗi: 404
# Lỗi khi crawl trang 1184773
# : HTTP 404
# Thử lại thất bại cho trang 1184773
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184247
# , mã lỗi: 404
# Lỗi khi crawl trang 1184247
# : HTTP 404
# Thử lại thất bại cho trang 1184247
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184624
# , mã lỗi: 404
# Lỗi khi crawl trang 1184624
# : HTTP 404
# Thử lại thất bại cho trang 1184624
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184930
# , mã lỗi: 404
# Lỗi khi crawl trang 1184930
# : HTTP 404
# Thử lại thất bại cho trang 1184930
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184856
# , mã lỗi: 404
# Lỗi khi crawl trang 1184856
# : HTTP 404
# Thử lại thất bại cho trang 1184856
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184789
# , mã lỗi: 404
# Lỗi khi crawl trang 1184789
# : HTTP 404
# Thử lại thất bại cho trang 1184789
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184970
# , mã lỗi: 404
# Lỗi khi crawl trang 1184970
# : HTTP 404
# Thử lại thất bại cho trang 1184970
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184866
# , mã lỗi: 404
# Lỗi khi crawl trang 1184866
# : HTTP 404
# Thử lại thất bại cho trang 1184866
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184787
# , mã lỗi: 404
# Lỗi khi crawl trang 1184787
# : HTTP 404
# Thử lại thất bại cho trang 1184787
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185046
# , mã lỗi: 404
# Lỗi khi crawl trang 1185046
# : HTTP 404
# Thử lại thất bại cho trang 1185046
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185006
# , mã lỗi: 404
# Lỗi khi crawl trang 1185006
# : HTTP 404
# Thử lại thất bại cho trang 1185006
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185028
# , mã lỗi: 404
# Lỗi khi crawl trang 1185028
# : HTTP 404
# Thử lại thất bại cho trang 1185028
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184998
# , mã lỗi: 404
# Lỗi khi crawl trang 1184998
# : HTTP 404
# Thử lại thất bại cho trang 1184998
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184884
# , mã lỗi: 404
# Lỗi khi crawl trang 1184884
# : HTTP 404
# Thử lại thất bại cho trang 1184884
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184996
# , mã lỗi: 404
# Lỗi khi crawl trang 1184996
# : HTTP 404
# Thử lại thất bại cho trang 1184996
# . Lưu ID vào file thất bại.
# Không lấy được trang 1184872
# , mã lỗi: 404
# Lỗi khi crawl trang 1184872
# : HTTP 404
# Thử lại thất bại cho trang 1184872
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185308
# , mã lỗi: 404
# Lỗi khi crawl trang 1185308
# : HTTP 404
# Thử lại thất bại cho trang 1185308
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185305
# , mã lỗi: 404
# Lỗi khi crawl trang 1185305
# : HTTP 404
# Thử lại thất bại cho trang 1185305
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185336
# , mã lỗi: 404
# Lỗi khi crawl trang 1185336
# : HTTP 404
# Thử lại thất bại cho trang 1185336
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185238
# , mã lỗi: 404
# Lỗi khi crawl trang 1185238
# : HTTP 404
# Thử lại thất bại cho trang 1185238
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185259
# , mã lỗi: 404
# Lỗi khi crawl trang 1185259
# : HTTP 404
# Thử lại thất bại cho trang 1185259
# . Lưu ID vào file thất bại.
# Không lấy được trang
# , mã lỗi: 404
# Lỗi khi crawl trang
# : HTTP 404
# Thử lại thất bại cho trang
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185309
# , mã lỗi: 404
# Lỗi khi crawl trang 1185309
# : HTTP 404
# Thử lại thất bại cho trang 1185309
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185318
# , mã lỗi: 404
# Lỗi khi crawl trang 1185318
# : HTTP 404
# Thử lại thất bại cho trang 1185318
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185334
# , mã lỗi: 404
# Lỗi khi crawl trang 1185334
# : HTTP 404
# Thử lại thất bại cho trang 1185334
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185332
# , mã lỗi: 404
# Lỗi khi crawl trang 1185332
# : HTTP 404
# Thử lại thất bại cho trang 1185332
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185321
# , mã lỗi: 404
# Lỗi khi crawl trang 1185321
# : HTTP 404
# Thử lại thất bại cho trang 1185321
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185322
# , mã lỗi: 404
# Lỗi khi crawl trang 1185322
# : HTTP 404
# Thử lại thất bại cho trang 1185322
# . Lưu ID vào file thất bại.
# Không lấy được trang 1185319
# , mã lỗi: 404
# Lỗi khi crawl trang 1185319
# : HTTP 404
# Thử lại thất bại cho trang 1185319
# . Lưu ID vào file thất bại.
# Đã lưu 298 trang vào file '/kaggle/working/wki-faild.csv'
# Hoàn thành nhóm 13/13!
